# %%
import pandas as pd 

df = pd.read_excel(r'C:\Users\Vusal\testanaconda\new_data.xlsx')

# %%
df.head()
# Out:
#    Qiymət               C1               C2  Kateqoriya Mərtəbə   Sahə  \
# 0   94500   40402511534715  498518545575805           0     5/5   53.0
# 1  126500   40404505013218  498509533353515           0     4/5   72.0
# 2  285000  404065973528723   49873263732787           1    4/18  122.2
# 3   87000  403766022856081  498478599128418           0     2/3   40.0
# 4   75000  404028671018614   49870570791354           0     3/5   30.0
#
#    Otaq sayı  Kupça  İpoteka  Təmir
# 0          2      1        0      1
# 1          3      1        0      1
# 2          3      1        0      1
# 3          2      1        0      0
# 4          2      1        0      1

# %%
df.columns = ['Price', 'C1', 'C2', 'Category', 'Floor', 'Area', 'RoomNumber', 'Kupcha', 'Mortgage', 'Remont']

# %%
df.head()
# Out:
#     Price               C1               C2  Category  Floor   Area  \
# 0   94500   40402511534715  498518545575805         0    5/5   53.0
# 1  126500   40404505013218  498509533353515         0    4/5   72.0
# 2  285000  404065973528723   49873263732787         1   4/18  122.2
# 3   87000  403766022856081  498478599128418         0    2/3   40.0
# 4   75000  404028671018614   49870570791354         0    3/5   30.0
#
#    RoomNumber  Kupcha  Mortgage  Remont
# 0           2       1         0       1
# 1           3       1         0       1
# 2           3       1         0       1
# 3           2       1         0       0
# 4           2       1         0       1

# %%
df.isna().sum()
# Out:
# Price         0
# C1            0
# C2            0
# Category      0
# Floor         0
# Area          0
# RoomNumber    0
# Kupcha        0
# Mortgage      0
# Remont        0
# dtype: int64

# %%
df['Floor_Home' ] = df.Floor.apply(lambda x: int(x.split('/')[0]))
df['Floor_House'] = df.Floor.apply(lambda x: int(x.split('/')[1]))

# %%
df.drop('Floor', axis = 1, inplace = True)

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#        Price         C1         C2  Category   Area  RoomNumber  Kupcha  \
# 0      94500  40.402512  49.851855         0   53.0           2       1
# 1     126500  40.404505  49.850953         0   72.0           3       1
# 2     285000  40.406597  49.873264         1  122.2           3       1
# 3      87000  40.376602  49.847860         0   40.0           2       1
# 4      75000  40.402867  49.870571         0   30.0           2       1
# ...      ...        ...        ...       ...    ...         ...     ...
# 1927  100000  40.406123  49.875201         0   55.0           2       1
# 1928  175000  40.398871  49.876368         1  101.0           3       1
# 1929   83000  40.397745  49.858017         0   41.0           2       1
# 1930  140000  40.397848  49.874338         1   70.0           2       1
# 1931  139000  40.404403  49.853603         1   62.0           3       1
#
#       Mortgage  Remont  Floor_Home  Floor_House
# 0            0       1           5            5
# 1            0       1           4            5
# 2            0       1           4           18
# 3            0       0           2            3
# 4            0       1           3            5
# ...        ...     ...         ...          ...
# 1927         0       1           7            9
# 1928         1       1          16           16
# 1929         0       1           1            9
# 1930         0       1           7            8
# 1931         0       1           4            4
#
# [1932 rows x 11 columns]

# %%
def extractCoordinates(col):
    col = str(col)
    col = col[:2] + '.' + col[2:]
    return float(col)

df['C1'] = df['C1'].apply(extractCoordinates)
df['C2'] = df['C2'].apply(extractCoordinates)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21288\1104811921.py in <module>
#       4     return float(col)
#       5
# ----> 6 df['C1'] = df['C1'].apply(extractCoordinates)
#       7 df['C2'] = df['C2'].apply(extractCoordinates)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_21288\1104811921.py in extractCoordinates(col)
#       2     col = str(col)
#       3     col = col[:2] + '.' + col[2:]
# ----> 4     return float(col)
#       5
#       6 df['C1'] = df['C1'].apply(extractCoordinates)
#
# ValueError: could not convert string to float: '40..402511534715'

# %%
df.dtypes
# Out:
# index            int64
# Price            int64
# C1             float64
# C2             float64
# Category         int64
# Area           float64
# RoomNumber       int64
# Kupcha           int64
# Mortgage         int64
# Remont           int64
# Floor_Home       int64
# Floor_House      int64
# dtype: object

# %%
import geopy.distance

def calculateDistance(c1, c2):
    return geopy.distance.geodesic(c1, c2).km
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21288\1857465504.py in <module>
# ----> 1 import geopy.distance
#       2
#       3 def calculateDistance(c1, c2):
#       4     return geopy.distance.geodesic(c1, c2).km
#
# ModuleNotFoundError: No module named 'geopy'

# %%
calculateDistance((df.C1[0], df.C2[0]), (df.C1[5], df.C2[5]))

# %%
metroCoordinates = [
    (40.3798499,49.8485742), #28May
    (40.4004909,49.8506117), #Ganjlik
    (40.4028298,49.8684909)] #Narimanov

# %%
diction = {}
index = 0
for i, j in zip(df['C1'], df['C2']):
    house_coordinates = tuple((i, j))
    distances = []
    for m in metroCoordinates:
        distances.append(calculateDistance(m, house_coordinates))
    diction[index] = (min(distances) * 1000)
    index+=1

# %%
distances = pd.DataFrame(diction, index = range(len(df))).T

distances.reset_index(inplace = True)
distances = distances[['index', 0]]
distances.rename({0:'DistanceToMetro'}, axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21288\3139291613.py in <module>
# ----> 1 distances = pd.DataFrame(diction, index = range(len(df))).T
#       2
#       3 distances.reset_index(inplace = True)
#       4 distances = distances[['index', 0]]
#       5 distances.rename({0:'DistanceToMetro'}, axis = 1, inplace = True)
#
# NameError: name 'diction' is not defined

# %%
distances

# %%
df.merge(distances, on = 'index', how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21288\724780025.py in <module>
# ----> 1 df.merge(distances, on = 'index', how = 'inner')
#
# NameError: name 'distances' is not defined

# %%
df.drop('index', axis = 1, inplace = True)

# %%
df.head()
# Out:
#     Price         C1         C2  Category   Area  RoomNumber  Kupcha  \
# 0   94500  40.402512  49.851855         0   53.0           2       1
# 1  126500  40.404505  49.850953         0   72.0           3       1
# 2  285000  40.406597  49.873264         1  122.2           3       1
# 3   87000  40.376602  49.847860         0   40.0           2       1
# 4   75000  40.402867  49.870571         0   30.0           2       1
#
#    Mortgage  Remont  Floor_Home  Floor_House
# 0         0       1           5            5
# 1         0       1           4            5
# 2         0       1           4           18
# 3         0       0           2            3
# 4         0       1           3            5
